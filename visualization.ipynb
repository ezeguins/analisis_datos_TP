# %%
# Import libraries
import numpy as np
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# import import_ipynb
# Se ignoran los "FutureWarnings" molestos
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Read cvs file
DATASET_PATH = 'weatherAUS.csv'
dataset = pd.read_csv(DATASET_PATH)

# %%
# Visualizamos la distribución de cada columna
def display_distributions(dataset):
    fig = dataset.hist(xlabelsize=12, ylabelsize=12,figsize=(22,10), color='blue', bins=20)
    [x.title.set_size(14) for x in fig.ravel()]
    plt.tight_layout()
    plt.show()
display_distributions(dataset)

# %%
# Graficamos la matriz de colinearidad
correlation_matrix = dataset[dataset.columns].corr().round(2)
fig,axes = plt.subplots(1,1,figsize=(20,8))
[t.set_color('white') for t in axes.xaxis.get_ticklabels()]
[t.set_color('white') for t in axes.yaxis.get_ticklabels()]
sns.heatmap(data=np.abs(correlation_matrix), annot=True,ax=axes,cmap='Greens');

# %%
# muy alta correlación entre Temp9am y MinTemp. También entre Temp3pm y MaxTemp, como es lógico. Podríamos eliminar dos variables
